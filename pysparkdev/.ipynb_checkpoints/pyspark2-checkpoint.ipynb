# %%
donutfile = '/mnt/Downloads/testdata/1253_HODVD_A3_404_A2/Data/donut-data-set.csv'
donut_raw = sc.textFile(donutfile)
donut_raw = donut_raw.map(lambda x: x.replace("\"" , "")).filter(lambda row: row <> '')

# %%
donut_hdr = donut_raw.first()  #returns string row with commas

# %%
donut_data = donut_raw.filter(lambda x: x<> donut_hdr)

# %%
donut_data.take(5)
# Out:
# [u'0.923307513352484,0.0135197141207755,21,2,4,8,0.852496764213146,0.0124828536260896,0.000182782669907495,0.923406490600458,0.0778750292332978,0.644866125183976,1',
#  u'0.711011884035543,0.909141522599384,22,2,3,9,0.505537899239772,0.64641042683833,0.826538308114327,1.15415605849213,0.953966686673604,0.46035073663368,1',
#  u'0.75118898646906,0.836567111080512,23,2,3,9,0.564284893392414,0.62842000028592,0.699844531341594,1.12433510339845,0.872783737128441,0.419968245447719,1',
#  u'0.308209649519995,0.418023289414123,24,1,5,1,0.094993188057238,0.128838811521522,0.174743470492603,0.519361780024138,0.808280495564412,0.208575453051705,1',
#  u'0.849057961953804,0.500220163026825,25,1,5,2,0.720899422757147,0.424715912147755,0.250220211498583,0.985454024425153,0.52249756970547,0.349058031386046,1']

# %%
def convert_li_2float(mylist): 
    l = []
    for c in mylist:
        l.append(float(c))
    return l

# %%
convert_li_2float(mylist)
# Out:
# [1.0, 2.0]

# %%
donuts = donut_data.map(lambda row: row.split(",")).map(lambda r2 : convert_li_2float(r2)).\
            map(lambda r3: dict(zip(donut_hdr.split(","), r3)))

# %%
df1  = sqlContext.createDataFrame(donuts)

# %%
df1.printSchema()
# Out:
# root
#  |-- a: double (nullable = true)
#  |-- b: double (nullable = true)
#  |-- bias: double (nullable = true)
#  |-- c: double (nullable = true)
#  |-- color: double (nullable = true)
#  |-- k: double (nullable = true)
#  |-- k0: double (nullable = true)
#  |-- shape: double (nullable = true)
#  |-- x: double (nullable = true)
#  |-- xx: double (nullable = true)
#  |-- xy: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- yy: double (nullable = true)

# %%
df1.show()
# Out:
# +-----------------+------------------+----+-----------------+-----+---+----+-----+------------------+-------------------+------------------+------------------+-------------------+
# |                a|                 b|bias|                c|color|  k|  k0|shape|                 x|                 xx|                xy|                 y|                 yy|
# +-----------------+------------------+----+-----------------+-----+---+----+-----+------------------+-------------------+------------------+------------------+-------------------+
# |0.923406490600458|0.0778750292332978| 1.0|0.644866125183976|  2.0|4.0| 8.0| 21.0| 0.923307513352484|  0.852496764213146|0.0124828536260896|0.0135197141207755|1.82782669907495E-4|
# | 1.15415605849213| 0.953966686673604| 1.0| 0.46035073663368|  2.0|3.0| 9.0| 22.0| 0.711011884035543|  0.505537899239772|  0.64641042683833| 0.909141522599384|  0.826538308114327|
# | 1.12433510339845| 0.872783737128441| 1.0|0.419968245447719|  2.0|3.0| 9.0| 23.0|  0.75118898646906|  0.564284893392414|  0.62842000028592| 0.836567111080512|  0.699844531341594|
# |0.519361780024138| 0.808280495564412| 1.0|0.208575453051705|  1.0|5.0| 1.0| 24.0| 0.308209649519995|  0.094993188057238| 0.128838811521522| 0.418023289414123|  0.174743470492603|
# |0.985454024425153|  0.52249756970547| 1.0|0.349058031386046|  1.0|5.0| 2.0| 25.0| 0.849057961953804|  0.720899422757147| 0.424715912147755| 0.500220163026825|  0.250220211498583|
# |0.492112681164801|  1.04613986717142| 1.0| 0.42632955896436|  2.0|6.0| 1.0| 21.0|0.0738831346388906|0.00545871758406844|0.0359467208248278| 0.486534863477573|   0.23671617337914|
# |0.613229772009826| 0.387651566219268| 1.0|0.492652707029903|  2.0|4.0|10.0| 22.0| 0.612888508243486|  0.375632323536926|0.0125369747681119|0.0204555552918464|4.18429742297785E-4|
# |0.955584610897845|  1.22425602987611| 1.0|0.522604151014326|  2.0|1.0| 4.0| 23.0| 0.207169560948387| 0.0429192269835473| 0.193259634985281| 0.932857288978994|  0.870222721601238|
# |0.593292308854389| 0.856423069092351| 1.0| 0.19083668584541|  1.0|5.0| 1.0| 24.0| 0.309267645236105| 0.0956464763898851| 0.156585139973909| 0.506309477845207|  0.256349287355886|
# |0.806130448165285| 0.273277419610556| 1.0|0.436273561610666|  2.0|4.0|10.0| 25.0|  0.78758287569508|  0.620286786088131| 0.135408181241926| 0.171928803203627| 0.0295595133710317|
# | 0.93358620577618| 0.105409523078414| 1.0|0.601936228937031|  2.0|4.0| 8.0| 21.0| 0.930236018029973|   0.86533904924026|0.0735072146828825|0.0790199618786573|0.00624415437530446|
# |0.667890882268509| 0.984077887735915| 1.0|0.288991338582386|  1.0|5.0| 1.0| 22.0| 0.238834470743313| 0.0570419044152386| 0.148967690904034| 0.623727766098455|  0.389036326202168|
# | 1.15825557675997| 0.819027144096042| 1.0|0.451518508649315|  2.0|3.0| 7.0| 23.0|  0.83537525916472|  0.697851823624524| 0.670231393002335| 0.802311758277938|  0.643704157471036|
# |0.730851925374252| 0.469706197095164| 1.0|0.238209090579297|  1.0|5.0| 3.0| 24.0| 0.656760312616825|   0.43133410822855| 0.210584055746134| 0.320640653371811|  0.102810428594702|
# |0.213906413126907|  0.82715035810576| 1.0|0.500636870310341|  2.0|2.0| 5.0| 25.0| 0.180789119331166| 0.0326847056685386|0.0206695401642766| 0.114329558331519| 0.0130712479082803|
# |0.991911469626425|  0.06189432159595| 1.0|0.657855445853466|  2.0|4.0| 8.0| 21.0| 0.990028728265315|  0.980156882790638|0.0604767440857932| 0.061085847672075|0.00373148078581595|
# | 1.22916052895905|   1.0034776167754| 1.0|0.535321288127727|  2.0|3.0| 9.0| 22.0| 0.751934139290825|  0.565404949831033| 0.731130065509666| 0.972332585137337|  0.945430656119858|
# |  0.5688118159807|   1.0250468432682| 1.0|  0.3673168690368|  2.0|6.0| 1.0| 23.0| 0.136412925552577| 0.0186084862578129|0.0753288918452558| 0.552212274167687|  0.304938395741448|
# |0.581302170866406|  0.43819729534628| 1.0|0.408368525870829|  2.0|4.0|10.0| 24.0|   0.5729476721026|  0.328269034967789|0.0562632831160512|0.0981996888294816|  0.009643178886207|
# |0.560702414192882| 0.649397107420365| 1.0|0.169357302283512|  1.0|5.0| 3.0| 25.0| 0.446335297077894|  0.199215197417612| 0.151472811718508| 0.339370004367083|  0.115171999864114|
# +-----------------+------------------+----+-----------------+-----+---+----+-----+------------------+-------------------+------------------+------------------+-------------------+
# only showing top 20 rows
