# %%
import matplotlib as mt
import json as js

# %%
# %ls sampledata/
# Out:
# August2017PD.xls              nypopulationbyzip.json  winequality-red.csv
# Groceries062014to022015.csv*  PRIOwartime_deaths.xls

# %% [markdown]
# # Open Json file

# %%
f = "sampledata/nypopulationbyzip.json"
with open(f, "r")  as json_file:
    json_data = js.load(json_file)

# %%
type(json_data)
# Out:
# dict

# %%
json_data.keys()
# Out:
# [u'meta', u'data']

# %%
json_meta_cols = json_data["meta"]["view"]["columns"]

# %%
for c in json_meta_cols:
    print(c["name"] , c["dataTypeName"])
# Out:
# (u'sid', u'meta_data')
# (u'id', u'meta_data')
# (u'position', u'meta_data')
# (u'created_at', u'meta_data')
# (u'created_meta', u'meta_data')
# (u'updated_at', u'meta_data')
# (u'updated_meta', u'meta_data')
# (u'meta', u'meta_data')
# (u'JURISDICTION NAME', u'number')
# (u'COUNT PARTICIPANTS', u'number')
# (u'COUNT FEMALE', u'number')
# (u'PERCENT FEMALE', u'number')
# (u'COUNT MALE', u'number')
# (u'PERCENT MALE', u'number')
# (u'COUNT GENDER UNKNOWN', u'number')
# (u'PERCENT GENDER UNKNOWN', u'number')
# (u'COUNT GENDER TOTAL', u'number')
# (u'PERCENT GENDER TOTAL', u'number')
# (u'COUNT PACIFIC ISLANDER', u'number')
# (u'PERCENT PACIFIC ISLANDER', u'number')
# (u'COUNT HISPANIC LATINO', u'number')
# (u'PERCENT HISPANIC LATINO', u'number')
# (u'COUNT AMERICAN INDIAN', u'number')
# (u'PERCENT AMERICAN INDIAN', u'number')
# (u'COUNT ASIAN NON HISPANIC', u'number')
# (u'PERCENT ASIAN NON HISPANIC', u'number')
# (u'COUNT WHITE NON HISPANIC', u'number')
# ...

# %%
for key , value in json_data.items():
    print (key + ":" , value)
# Out:
# (u'meta:', {u'view': {u'newBackend': False, u'grants': [{u'flags': [u'public'], u'type': u'viewer', u'inherited': False}], u'publicationDate': 1372266760, u'viewLastModified': 1409940379, u'owner': {u'displayName': u'NYC OpenData', u'rights': [u'create_datasets', u'edit_others_datasets', u'edit_sdp', u'edit_site_theme', u'moderate_comments', u'manage_users', u'chown_datasets', u'edit_nominations', u'approve_nominations', u'feature_items', u'federations', u'manage_stories', u'manage_approval', u'change_configurations', u'view_domain', u'view_others_datasets', u'edit_pages', u'create_pages', u'view_goals', u'view_dashboards', u'edit_goals', u'edit_dashboards', u'create_dashboards', u'manage_provenance', u'create_story', u'edit_story_title_desc', u'create_story_copy', u'delete_story', u'manage_story_collaborators', u'manage_story_visibility', u'manage_story_public_version', u'edit_story', u'view_unpublished_story', u'view_story', u'view_all_dataset_status_logs', u'use_data_connectors', 
# ...

# %%
json_file.close
# Out:
# <function close>
