# %%
#with MySql demo
from sqlalchemy import create_engine

# %%
help(create_engine)
# Out:
# Help on function create_engine in module sqlalchemy.engine:
#
# create_engine(*args, **kwargs)
#     Create a new :class:`.Engine` instance.
#
#     The standard calling form is to send the URL as the
#     first positional argument, usually a string
#     that indicates database dialect and connection arguments::
#
#
#         engine = create_engine("postgresql://scott:tiger@localhost/test")
#
#     Additional keyword arguments may then follow it which
#     establish various options on the resulting :class:`.Engine`
#     and its underlying :class:`.Dialect` and :class:`.Pool`
#     constructs::
#
#         engine = create_engine("mysql://scott:tiger@hostname/dbname",
#                                     encoding='latin1', echo=True)
#
#     The string form of the URL is
#     ``dialect[+driver]://user:password@host/dbname[?key=value..]``, where
#     ``dialect`` is a database name such as ``mysql``, ``oracle``,
# ...

# %%
engine = create_engine("mysql://talend:talend@localhost/talendDF", encoding='latin1', echo=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-1cfa9d23edaa> in <module>()
# ----> 1 engine = create_engine("mysql://talend:talend@localhost/talendDF", encoding='latin1', echo=True)
#
# /home/jamie/pysparkdev/local/lib/python2.7/site-packages/sqlalchemy/engine/__init__.pyc in create_engine(*args, **kwargs)
#     385     strategy = kwargs.pop('strategy', default_strategy)
#     386     strategy = strategies.strategies[strategy]
# --> 387     return strategy.create(*args, **kwargs)
#     388
#     389
#
# /home/jamie/pysparkdev/local/lib/python2.7/site-packages/sqlalchemy/engine/strategies.pyc in create(self, name_or_url, **kwargs)
#      78                 if k in kwargs:
#      79                     dbapi_args[k] = pop_kwarg(k)
# ---> 80             dbapi = dialect_cls.dbapi(**dbapi_args)
#      81
#      82         dialect_args['dbapi'] = dbapi
#
# ...
